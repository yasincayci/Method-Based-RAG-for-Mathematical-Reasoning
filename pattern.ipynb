# %% [markdown]
# # Pattern Sonuçlar

# %%
import os
from dotenv import load_dotenv
from rag_helper import RAGEvaluator, OUTPUT_DIR

# =============================================================================
# MAIN EXECUTION
# =============================================================================
print("\n" + "="*80)
print("LLM RAG EVALUATION")
print("="*80)

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY_5")

if not GOOGLE_API_KEY:
    print("❌ GOOGLE_API_KEY not found in environment!")
    print("   Add to .env: GOOGLE_API_KEY=your_key_here")
    raise ValueError("Missing GOOGLE_API_KEY")

# Initialize evaluator
evaluator = RAGEvaluator(api_key=GOOGLE_API_KEY)

evaluator.evaluate_specific_db("pattern")

print("\n✅ Evaluation complete!")
print(f"📂 Results saved to: {OUTPUT_DIR}")
# Out:
# ================================================================================
# LLM RAG EVALUATION
# ================================================================================
#
# 📥 Loading embeddings and metadata...
# ✅ Loaded 1319 test samples
# ✅ Loaded 5 RAG databases
#
# ================================================================================
# 🚀 RAG EVALUATION: pattern
# ================================================================================
#
# 📝 Processing 1319 questions with RAG...
#    Method strategy: TRUNCATED (200 chars)
# RAG-pattern:   4%|▍         | 50/1319 [02:13<50:52,  2.41s/it]
#   Progress: 50/1319
#   Overall Acc: 42.0%
#   With Methods: 45.0% (18/40)
#   Without Methods: 30.0% (3/10)
#   Errors: 0
# RAG-pattern:   8%|▊         | 100/1319 [04:21<55:59,  2.76s/it]
#   Progress: 100/1319
#   Overall Acc: 43.0%
#   With Methods: 41.0% (32/78)
#   Without Methods: 50.0% (11/22)
#   Errors: 0
# RAG-pattern:  11%|█▏        | 150/1319 [06:27<50:12,  2.58s/it]
#   Progress: 150/1319
#   Overall Acc: 44.7%
#   With Methods: 43.8% (49/112)
#   Without Methods: 47.4% (18/38)
#   Errors: 0
# RAG-pattern:  15%|█▌        | 200/1319 [08:43<54:15,  2.91s/it]
#   Progress: 200/1319
#   Overall Acc: 42.5%
#   With Methods: 42.4% (64/151)
#   Without Methods: 42.9% (21/49)
#   Errors: 0
# RAG-pattern:  19%|█▉        | 250/1319 [10:52<44:05,  2.47s/it]
#   Progress: 250/1319
#   Overall Acc: 44.4%
#   With Methods: 44.3% (85/192)
#   Without Methods: 44.8% (26/58)
#   Errors: 0
# RAG-pattern:  23%|██▎       | 300/1319 [13:03<47:50,  2.82s/it]
#   Progress: 300/1319
#   Overall Acc: 46.0%
#   With Methods: 46.6% (108/232)
#   Without Methods: 44.1% (30/68)
#   Errors: 0
# RAG-pattern:  27%|██▋       | 350/1319 [15:16<40:53,  2.53s/it]
#   Progress: 350/1319
#   Overall Acc: 46.0%
#   With Methods: 46.0% (121/263)
#   Without Methods: 46.0% (40/87)
#   Errors: 0
# RAG-pattern:  30%|███       | 400/1319 [17:26<40:17,  2.63s/it]
#   Progress: 400/1319
#   Overall Acc: 45.8%
#   With Methods: 45.5% (137/301)
#   Without Methods: 46.5% (46/99)
#   Errors: 0
# RAG-pattern:  34%|███▍      | 450/1319 [19:35<33:37,  2.32s/it]
#   Progress: 450/1319
#   Overall Acc: 45.1%
#   With Methods: 44.6% (148/332)
#   Without Methods: 46.6% (55/118)
#   Errors: 0
# RAG-pattern:  38%|███▊      | 500/1319 [21:38<33:35,  2.46s/it]
#   Progress: 500/1319
#   Overall Acc: 47.2%
#   With Methods: 46.6% (172/369)
#   Without Methods: 48.9% (64/131)
#   Errors: 0
# RAG-pattern:  42%|████▏     | 550/1319 [23:48<30:23,  2.37s/it]
#   Progress: 550/1319
#   Overall Acc: 47.3%
#   With Methods: 47.2% (191/405)
#   Without Methods: 47.6% (69/145)
#   Errors: 0
# RAG-pattern:  45%|████▌     | 600/1319 [25:53<31:41,  2.64s/it]
#   Progress: 600/1319
#   Overall Acc: 47.3%
#   With Methods: 47.6% (208/437)
#   Without Methods: 46.6% (76/163)
#   Errors: 0
# RAG-pattern:  49%|████▉     | 650/1319 [27:59<30:00,  2.69s/it]
#   Progress: 650/1319
#   Overall Acc: 47.8%
#   With Methods: 48.3% (228/472)
#   Without Methods: 46.6% (83/178)
#   Errors: 0
# RAG-pattern:  53%|█████▎    | 700/1319 [30:07<26:03,  2.53s/it]
#   Progress: 700/1319
#   Overall Acc: 48.0%
#   With Methods: 48.2% (246/510)
#   Without Methods: 47.4% (90/190)
#   Errors: 0
# RAG-pattern:  57%|█████▋    | 750/1319 [32:16<27:26,  2.89s/it]
#   Progress: 750/1319
#   Overall Acc: 48.1%
#   With Methods: 48.3% (263/544)
#   Without Methods: 47.6% (98/206)
#   Errors: 0
# RAG-pattern:  61%|██████    | 800/1319 [34:21<20:42,  2.39s/it]
#   Progress: 800/1319
#   Overall Acc: 48.0%
#   With Methods: 48.0% (280/583)
#   Without Methods: 47.9% (104/217)
#   Errors: 0
# RAG-pattern:  64%|██████▍   | 850/1319 [36:36<19:58,  2.55s/it]
#   Progress: 850/1319
#   Overall Acc: 47.4%
#   With Methods: 47.3% (296/626)
#   Without Methods: 47.8% (107/224)
#   Errors: 0
# RAG-pattern:  68%|██████▊   | 900/1319 [38:44<17:36,  2.52s/it]
#   Progress: 900/1319
#   Overall Acc: 47.6%
#   With Methods: 47.7% (317/665)
#   Without Methods: 47.2% (111/235)
#   Errors: 0
# RAG-pattern:  72%|███████▏  | 950/1319 [40:52<13:57,  2.27s/it]
#   Progress: 950/1319
#   Overall Acc: 47.8%
#   With Methods: 48.2% (339/703)
#   Without Methods: 46.6% (115/247)
#   Errors: 0
# RAG-pattern:  76%|███████▌  | 1000/1319 [43:07<14:57,  2.81s/it]
#   Progress: 1000/1319
#   Overall Acc: 47.3%
#   With Methods: 47.8% (351/735)
#   Without Methods: 46.0% (122/265)
#   Errors: 0
# RAG-pattern:  80%|███████▉  | 1050/1319 [45:19<11:46,  2.63s/it]
#   Progress: 1050/1319
#   Overall Acc: 47.0%
#   With Methods: 47.5% (364/766)
#   Without Methods: 45.4% (129/284)
#   Errors: 0
# RAG-pattern:  83%|████████▎ | 1100/1319 [47:27<09:15,  2.54s/it]
#   Progress: 1100/1319
#   Overall Acc: 47.0%
#   With Methods: 47.8% (384/804)
#   Without Methods: 44.9% (133/296)
#   Errors: 0
# RAG-pattern:  87%|████████▋ | 1150/1319 [49:38<07:14,  2.57s/it]
#   Progress: 1150/1319
#   Overall Acc: 47.3%
#   With Methods: 48.1% (406/844)
#   Without Methods: 45.1% (138/306)
#   Errors: 0
# RAG-pattern:  91%|█████████ | 1200/1319 [51:50<04:59,  2.51s/it]
#   Progress: 1200/1319
#   Overall Acc: 46.9%
#   With Methods: 47.7% (419/878)
#   Without Methods: 44.7% (144/322)
#   Errors: 0
# RAG-pattern:  95%|█████████▍| 1250/1319 [53:59<03:10,  2.77s/it]
#   Progress: 1250/1319
#   Overall Acc: 47.0%
#   With Methods: 47.4% (434/915)
#   Without Methods: 45.7% (153/335)
#   Errors: 0
# RAG-pattern:  99%|█████████▊| 1300/1319 [56:03<00:45,  2.41s/it]
#   Progress: 1300/1319
#   Overall Acc: 46.7%
#   With Methods: 46.9% (448/955)
#   Without Methods: 46.1% (159/345)
#   Errors: 0
# RAG-pattern: 100%|██████████| 1319/1319 [56:51<00:00,  2.59s/it]
# ================================================================================
# ✅ pattern COMPLETE - DETAILED METRICS
# ================================================================================
#
# 📊 OVERALL PERFORMANCE:
#    Total Accuracy: 46.55% (614/1319)
#
# 🎯 METHOD USAGE:
#    Usage Rate: 73.6% (971/1319 questions)
#
# 📈 ACCURACY BREAKDOWN:
#    With Methods:    46.65% (453/971)
#    Without Methods: 46.26% (161/348)
#
# 💡 METHOD IMPACT:
#    Difference: +0.39 percentage points
#    ✅ Methods IMPROVE performance
#
# ❌ Errors: 0
# ================================================================================
#
# ✅ Evaluation complete!
# 📂 Results saved to: results\gemma3_1b_single_evaluation
