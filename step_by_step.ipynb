# %% [markdown]
# # Step by Step Sonuçlar

# %%
import os
from dotenv import load_dotenv
from rag_helper import RAGEvaluator, OUTPUT_DIR

# =============================================================================
# MAIN EXECUTION
# =============================================================================
print("\n" + "="*80)
print("LLM RAG EVALUATION")
print("="*80)

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY_2")

if not GOOGLE_API_KEY:
    print("❌ GOOGLE_API_KEY not found in environment!")
    print("   Add to .env: GOOGLE_API_KEY=your_key_here")
    raise ValueError("Missing GOOGLE_API_KEY")

# Initialize evaluator
evaluator = RAGEvaluator(api_key=GOOGLE_API_KEY)

evaluator.evaluate_specific_db("step_by_step")

print("\n✅ Evaluation complete!")
print(f"📂 Results saved to: {OUTPUT_DIR}")
# Out:
# ================================================================================
# LLM RAG EVALUATION
# ================================================================================
#
# 📥 Loading embeddings and metadata...
# ✅ Loaded 1319 test samples
# ✅ Loaded 5 RAG databases
#
# ================================================================================
# 🚀 RAG EVALUATION: step_by_step
# ================================================================================
#
# 📝 Processing 1319 questions with RAG...
#    Method strategy: TRUNCATED (200 chars)
# RAG-step_by_step:   4%|▍         | 50/1319 [02:10<52:00,  2.46s/it]
#   Progress: 50/1319
#   Overall Acc: 38.0%
#   With Methods: 35.1% (13/37)
#   Without Methods: 46.2% (6/13)
#   Errors: 0
# RAG-step_by_step:   8%|▊         | 100/1319 [04:18<59:13,  2.91s/it]
#   Progress: 100/1319
#   Overall Acc: 45.0%
#   With Methods: 41.1% (30/73)
#   Without Methods: 55.6% (15/27)
#   Errors: 0
# RAG-step_by_step:  11%|█▏        | 150/1319 [06:29<53:42,  2.76s/it]
#   Progress: 150/1319
#   Overall Acc: 41.3%
#   With Methods: 38.0% (41/108)
#   Without Methods: 50.0% (21/42)
#   Errors: 0
# RAG-step_by_step:  15%|█▌        | 200/1319 [08:43<51:41,  2.77s/it]
#   Progress: 200/1319
#   Overall Acc: 42.5%
#   With Methods: 38.7% (55/142)
#   Without Methods: 51.7% (30/58)
#   Errors: 0
# RAG-step_by_step:  19%|█▉        | 250/1319 [10:47<46:11,  2.59s/it]
#   Progress: 250/1319
#   Overall Acc: 44.8%
#   With Methods: 41.4% (75/181)
#   Without Methods: 53.6% (37/69)
#   Errors: 0
# RAG-step_by_step:  23%|██▎       | 300/1319 [12:50<45:11,  2.66s/it]
#   Progress: 300/1319
#   Overall Acc: 46.3%
#   With Methods: 43.1% (93/216)
#   Without Methods: 54.8% (46/84)
#   Errors: 0
# RAG-step_by_step:  27%|██▋       | 350/1319 [15:01<42:50,  2.65s/it]
#   Progress: 350/1319
#   Overall Acc: 47.7%
#   With Methods: 43.8% (110/251)
#   Without Methods: 57.6% (57/99)
#   Errors: 0
# RAG-step_by_step:  30%|███       | 400/1319 [17:14<35:40,  2.33s/it]
#   Progress: 400/1319
#   Overall Acc: 47.8%
#   With Methods: 44.7% (130/291)
#   Without Methods: 56.0% (61/109)
#   Errors: 0
# RAG-step_by_step:  34%|███▍      | 450/1319 [19:30<41:41,  2.88s/it]
#   Progress: 450/1319
#   Overall Acc: 46.2%
#   With Methods: 42.6% (140/329)
#   Without Methods: 56.2% (68/121)
#   Errors: 0
# RAG-step_by_step:  38%|███▊      | 500/1319 [21:30<31:48,  2.33s/it]
#   Progress: 500/1319
#   Overall Acc: 47.0%
#   With Methods: 43.4% (158/364)
#   Without Methods: 56.6% (77/136)
#   Errors: 0
# RAG-step_by_step:  42%|████▏     | 550/1319 [23:34<31:03,  2.42s/it]
#   Progress: 550/1319
#   Overall Acc: 46.9%
#   With Methods: 43.2% (172/398)
#   Without Methods: 56.6% (86/152)
#   Errors: 0
# RAG-step_by_step:  45%|████▌     | 600/1319 [25:39<30:37,  2.56s/it]
#   Progress: 600/1319
#   Overall Acc: 46.3%
#   With Methods: 43.0% (185/430)
#   Without Methods: 54.7% (93/170)
#   Errors: 0
# RAG-step_by_step:  49%|████▉     | 650/1319 [27:42<26:45,  2.40s/it]
#   Progress: 650/1319
#   Overall Acc: 45.7%
#   With Methods: 42.7% (197/461)
#   Without Methods: 52.9% (100/189)
#   Errors: 0
# RAG-step_by_step:  53%|█████▎    | 700/1319 [29:49<23:45,  2.30s/it]
#   Progress: 700/1319
#   Overall Acc: 46.1%
#   With Methods: 43.2% (216/500)
#   Without Methods: 53.5% (107/200)
#   Errors: 0
# RAG-step_by_step:  57%|█████▋    | 750/1319 [32:02<25:40,  2.71s/it]
#   Progress: 750/1319
#   Overall Acc: 46.5%
#   With Methods: 43.8% (235/536)
#   Without Methods: 53.3% (114/214)
#   Errors: 0
# RAG-step_by_step:  61%|██████    | 800/1319 [34:07<21:47,  2.52s/it]
#   Progress: 800/1319
#   Overall Acc: 46.5%
#   With Methods: 43.9% (254/578)
#   Without Methods: 53.2% (118/222)
#   Errors: 0
# RAG-step_by_step:  64%|██████▍   | 850/1319 [36:17<20:44,  2.65s/it]
#   Progress: 850/1319
#   Overall Acc: 46.7%
#   With Methods: 44.4% (276/621)
#   Without Methods: 52.8% (121/229)
#   Errors: 0
# RAG-step_by_step:  68%|██████▊   | 900/1319 [38:28<17:23,  2.49s/it]
#   Progress: 900/1319
#   Overall Acc: 46.6%
#   With Methods: 44.3% (293/661)
#   Without Methods: 52.7% (126/239)
#   Errors: 0
# RAG-step_by_step:  72%|███████▏  | 950/1319 [40:32<13:10,  2.14s/it]
#   Progress: 950/1319
#   Overall Acc: 46.3%
#   With Methods: 44.2% (307/695)
#   Without Methods: 52.2% (133/255)
#   Errors: 0
# RAG-step_by_step:  76%|███████▌  | 1000/1319 [42:41<14:21,  2.70s/it]
#   Progress: 1000/1319
#   Overall Acc: 45.8%
#   With Methods: 43.6% (316/725)
#   Without Methods: 51.6% (142/275)
#   Errors: 0
# RAG-step_by_step:  80%|███████▉  | 1050/1319 [44:55<11:54,  2.66s/it]
#   Progress: 1050/1319
#   Overall Acc: 45.2%
#   With Methods: 43.2% (328/759)
#   Without Methods: 50.5% (147/291)
#   Errors: 0
# RAG-step_by_step:  83%|████████▎ | 1100/1319 [47:01<08:23,  2.30s/it]
#   Progress: 1100/1319
#   Overall Acc: 45.2%
#   With Methods: 43.2% (345/799)
#   Without Methods: 50.5% (152/301)
#   Errors: 0
# RAG-step_by_step:  87%|████████▋ | 1150/1319 [49:08<06:46,  2.41s/it]
#   Progress: 1150/1319
#   Overall Acc: 45.5%
#   With Methods: 43.4% (361/832)
#   Without Methods: 50.9% (162/318)
#   Errors: 0
# RAG-step_by_step:  91%|█████████ | 1200/1319 [51:18<04:46,  2.41s/it]
#   Progress: 1200/1319
#   Overall Acc: 45.1%
#   With Methods: 42.8% (370/865)
#   Without Methods: 51.0% (171/335)
#   Errors: 0
# RAG-step_by_step:  95%|█████████▍| 1250/1319 [53:27<03:04,  2.68s/it]
#   Progress: 1250/1319
#   Overall Acc: 44.9%
#   With Methods: 42.6% (384/902)
#   Without Methods: 50.9% (177/348)
#   Errors: 0
# RAG-step_by_step:  99%|█████████▊| 1300/1319 [55:32<00:47,  2.51s/it]
#   Progress: 1300/1319
#   Overall Acc: 44.8%
#   With Methods: 42.4% (398/939)
#   Without Methods: 51.2% (185/361)
#   Errors: 0
# RAG-step_by_step: 100%|██████████| 1319/1319 [56:21<00:00,  2.56s/it]
# ================================================================================
# ✅ step_by_step COMPLETE - DETAILED METRICS
# ================================================================================
#
# 📊 OVERALL PERFORMANCE:
#    Total Accuracy: 44.81% (591/1319)
#
# 🎯 METHOD USAGE:
#    Usage Rate: 72.2% (952/1319 questions)
#
# 📈 ACCURACY BREAKDOWN:
#    With Methods:    42.33% (403/952)
#    Without Methods: 51.23% (188/367)
#
# 💡 METHOD IMPACT:
#    Difference: -8.89 percentage points
#    ⚠️  Methods DECREASE performance
#
# ❌ Errors: 0
# ================================================================================
#
# ✅ Evaluation complete!
# 📂 Results saved to: results\gemma3_1b_single_evaluation
