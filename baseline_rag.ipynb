# %% [markdown]
# ## Baseline Sonuçlar

# %%
import os
from dotenv import load_dotenv
from rag_helper import RAGEvaluator, OUTPUT_DIR

# =============================================================================
# MAIN EXECUTION
# =============================================================================
print("\n" + "="*80)
print("LLM RAG EVALUATION")
print("="*80)

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not GOOGLE_API_KEY:
    print("❌ GOOGLE_API_KEY not found in environment!")
    print("   Add to .env: GOOGLE_API_KEY=your_key_here")
    raise ValueError("Missing GOOGLE_API_KEY")

# Initialize evaluator
evaluator = RAGEvaluator(api_key=GOOGLE_API_KEY)

evaluator.evaluate_baseline()

print("\n✅ Evaluation complete!")
print(f"📂 Results saved to: {OUTPUT_DIR}")
# Out:
# ================================================================================
# LLM RAG EVALUATION
# ================================================================================
#
# 📥 Loading embeddings and metadata...
# ✅ Loaded 1319 test samples
# ✅ Loaded 5 RAG databases
#
# ================================================================================
# 🚀 BASELINE EVALUATION
# ================================================================================
#
# 📝 Processing 1319 questions...
# Baseline:   4%|▍         | 50/1319 [02:04<49:49,  2.36s/it]
#   Progress: 50/1319 | Acc: 38.0% | Errors: 0
# Baseline:   8%|▊         | 100/1319 [04:05<56:40,  2.79s/it]
#   Progress: 100/1319 | Acc: 46.0% | Errors: 0
# Baseline:  11%|█▏        | 150/1319 [06:02<48:30,  2.49s/it]
#   Progress: 150/1319 | Acc: 46.0% | Errors: 0
# Baseline:  15%|█▌        | 200/1319 [08:07<46:46,  2.51s/it]
#   Progress: 200/1319 | Acc: 45.0% | Errors: 0
# Baseline:  19%|█▉        | 250/1319 [10:08<40:40,  2.28s/it]
#   Progress: 250/1319 | Acc: 47.2% | Errors: 0
# Baseline:  23%|██▎       | 300/1319 [12:06<42:33,  2.51s/it]
#   Progress: 300/1319 | Acc: 47.7% | Errors: 0
# Baseline:  27%|██▋       | 350/1319 [14:14<45:15,  2.80s/it]
#   Progress: 350/1319 | Acc: 48.0% | Errors: 0
# Baseline:  30%|███       | 400/1319 [16:14<32:55,  2.15s/it]
#   Progress: 400/1319 | Acc: 48.2% | Errors: 0
# Baseline:  34%|███▍      | 450/1319 [18:20<33:58,  2.35s/it]
#   Progress: 450/1319 | Acc: 48.2% | Errors: 0
# Baseline:  38%|███▊      | 500/1319 [20:15<33:31,  2.46s/it]
#   Progress: 500/1319 | Acc: 49.0% | Errors: 0
# Baseline:  42%|████▏     | 550/1319 [22:15<31:48,  2.48s/it]
