# %% [markdown]
# # Error Aware Sonuçlar

# %%
import os
from dotenv import load_dotenv
from rag_helper import RAGEvaluator, OUTPUT_DIR

# =============================================================================
# MAIN EXECUTION
# =============================================================================
print("\n" + "="*80)
print("LLM RAG EVALUATION")
print("="*80)

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY_3")

if not GOOGLE_API_KEY:
    print("❌ GOOGLE_API_KEY not found in environment!")
    print("   Add to .env: GOOGLE_API_KEY=your_key_here")
    raise ValueError("Missing GOOGLE_API_KEY")

# Initialize evaluator
evaluator = RAGEvaluator(api_key=GOOGLE_API_KEY)

evaluator.evaluate_specific_db("error_aware")

print("\n✅ Evaluation complete!")
print(f"📂 Results saved to: {OUTPUT_DIR}")
# Out:
# ================================================================================
# LLM RAG EVALUATION
# ================================================================================
#
# 📥 Loading embeddings and metadata...
# ✅ Loaded 1319 test samples
# ✅ Loaded 5 RAG databases
#
# ================================================================================
# 🚀 RAG EVALUATION: error_aware
# ================================================================================
#
# 📝 Processing 1319 questions with RAG...
#    Method strategy: TRUNCATED (200 chars)
# RAG-error_aware:   4%|▍         | 50/1319 [02:13<53:35,  2.53s/it]
#   Progress: 50/1319
#   Overall Acc: 36.0%
#   With Methods: 34.1% (14/41)
#   Without Methods: 44.4% (4/9)
#   Errors: 0
# RAG-error_aware:   8%|▊         | 100/1319 [04:17<56:50,  2.80s/it]
#   Progress: 100/1319
#   Overall Acc: 45.0%
#   With Methods: 41.6% (32/77)
#   Without Methods: 56.5% (13/23)
#   Errors: 0
# RAG-error_aware:  11%|█▏        | 150/1319 [06:25<45:19,  2.33s/it]
#   Progress: 150/1319
#   Overall Acc: 42.0%
#   With Methods: 38.8% (45/116)
#   Without Methods: 52.9% (18/34)
#   Errors: 0
# RAG-error_aware:  15%|█▌        | 200/1319 [08:39<53:18,  2.86s/it]
#   Progress: 200/1319
#   Overall Acc: 42.0%
#   With Methods: 39.9% (63/158)
#   Without Methods: 50.0% (21/42)
#   Errors: 0
# RAG-error_aware:  19%|█▉        | 250/1319 [10:46<49:26,  2.77s/it]
#   Progress: 250/1319
#   Overall Acc: 43.2%
#   With Methods: 40.6% (82/202)
#   Without Methods: 54.2% (26/48)
#   Errors: 0
# RAG-error_aware:  23%|██▎       | 300/1319 [12:57<45:32,  2.68s/it]
#   Progress: 300/1319
#   Overall Acc: 45.0%
#   With Methods: 42.7% (103/241)
#   Without Methods: 54.2% (32/59)
#   Errors: 0
# RAG-error_aware:  27%|██▋       | 350/1319 [15:10<45:54,  2.84s/it]
#   Progress: 350/1319
#   Overall Acc: 44.9%
#   With Methods: 42.2% (116/275)
#   Without Methods: 54.7% (41/75)
#   Errors: 0
# RAG-error_aware:  30%|███       | 400/1319 [17:23<34:35,  2.26s/it]
#   Progress: 400/1319
#   Overall Acc: 45.0%
#   With Methods: 42.9% (137/319)
#   Without Methods: 53.1% (43/81)
#   Errors: 0
# RAG-error_aware:  34%|███▍      | 450/1319 [19:40<42:12,  2.91s/it]
#   Progress: 450/1319
#   Overall Acc: 44.2%
#   With Methods: 42.0% (150/357)
#   Without Methods: 52.7% (49/93)
#   Errors: 0
# RAG-error_aware:  38%|███▊      | 500/1319 [21:46<34:44,  2.54s/it]
#   Progress: 500/1319
#   Overall Acc: 46.2%
#   With Methods: 44.1% (176/399)
#   Without Methods: 54.5% (55/101)
#   Errors: 0
# RAG-error_aware:  42%|████▏     | 550/1319 [23:56<33:26,  2.61s/it]
#   Progress: 550/1319
#   Overall Acc: 45.8%
#   With Methods: 44.0% (194/441)
#   Without Methods: 53.2% (58/109)
#   Errors: 0
# RAG-error_aware:  45%|████▌     | 600/1319 [26:07<31:57,  2.67s/it]
#   Progress: 600/1319
#   Overall Acc: 45.8%
#   With Methods: 44.6% (214/480)
#   Without Methods: 50.8% (61/120)
#   Errors: 0
# RAG-error_aware:  49%|████▉     | 650/1319 [28:14<29:51,  2.68s/it]
#   Progress: 650/1319
#   Overall Acc: 46.3%
#   With Methods: 44.9% (232/517)
#   Without Methods: 51.9% (69/133)
#   Errors: 0
# RAG-error_aware:  53%|█████▎    | 700/1319 [30:21<25:01,  2.43s/it]
#   Progress: 700/1319
#   Overall Acc: 46.9%
#   With Methods: 44.9% (249/555)
#   Without Methods: 54.5% (79/145)
#   Errors: 0
# RAG-error_aware:  57%|█████▋    | 750/1319 [32:34<26:58,  2.85s/it]
#   Progress: 750/1319
#   Overall Acc: 47.2%
#   With Methods: 45.4% (271/597)
#   Without Methods: 54.2% (83/153)
#   Errors: 0
# RAG-error_aware:  61%|██████    | 800/1319 [34:43<21:26,  2.48s/it]
#   Progress: 800/1319
#   Overall Acc: 47.0%
#   With Methods: 45.1% (288/638)
#   Without Methods: 54.3% (88/162)
#   Errors: 0
# RAG-error_aware:  64%|██████▍   | 850/1319 [36:55<20:08,  2.58s/it]
#   Progress: 850/1319
#   Overall Acc: 46.9%
#   With Methods: 45.1% (307/680)
#   Without Methods: 54.1% (92/170)
#   Errors: 0
# RAG-error_aware:  68%|██████▊   | 900/1319 [39:03<16:53,  2.42s/it]
#   Progress: 900/1319
#   Overall Acc: 47.6%
#   With Methods: 45.8% (330/720)
#   Without Methods: 54.4% (98/180)
#   Errors: 0
# RAG-error_aware:  72%|███████▏  | 950/1319 [41:10<14:13,  2.31s/it]
#   Progress: 950/1319
#   Overall Acc: 47.8%
#   With Methods: 46.4% (353/760)
#   Without Methods: 53.2% (101/190)
#   Errors: 0
# RAG-error_aware:  76%|███████▌  | 1000/1319 [43:24<15:44,  2.96s/it]
#   Progress: 1000/1319
#   Overall Acc: 47.2%
#   With Methods: 45.6% (361/792)
#   Without Methods: 53.4% (111/208)
#   Errors: 0
# RAG-error_aware:  80%|███████▉  | 1050/1319 [45:39<11:40,  2.60s/it]
#   Progress: 1050/1319
#   Overall Acc: 46.6%
#   With Methods: 44.9% (373/830)
#   Without Methods: 52.7% (116/220)
#   Errors: 0
# RAG-error_aware:  83%|████████▎ | 1100/1319 [47:47<09:01,  2.47s/it]
#   Progress: 1100/1319
#   Overall Acc: 46.4%
#   With Methods: 44.8% (390/871)
#   Without Methods: 52.4% (120/229)
#   Errors: 0
# RAG-error_aware:  87%|████████▋ | 1150/1319 [49:58<07:27,  2.65s/it]
#   Progress: 1150/1319
#   Overall Acc: 46.6%
#   With Methods: 45.3% (413/912)
#   Without Methods: 51.7% (123/238)
#   Errors: 0
# RAG-error_aware:  91%|█████████ | 1200/1319 [52:06<04:30,  2.28s/it]
#   Progress: 1200/1319
#   Overall Acc: 46.2%
#   With Methods: 44.9% (426/949)
#   Without Methods: 51.0% (128/251)
#   Errors: 0
# RAG-error_aware:  95%|█████████▍| 1250/1319 [54:17<03:13,  2.81s/it]
#   Progress: 1250/1319
#   Overall Acc: 45.9%
#   With Methods: 44.5% (441/990)
#   Without Methods: 51.2% (133/260)
#   Errors: 0
# RAG-error_aware:  99%|█████████▊| 1300/1319 [56:25<00:50,  2.66s/it]
#   Progress: 1300/1319
#   Overall Acc: 45.6%
#   With Methods: 44.0% (454/1032)
#   Without Methods: 51.9% (139/268)
#   Errors: 0
# RAG-error_aware: 100%|██████████| 1319/1319 [57:15<00:00,  2.60s/it]
# ================================================================================
# ✅ error_aware COMPLETE - DETAILED METRICS
# ================================================================================
#
# 📊 OVERALL PERFORMANCE:
#    Total Accuracy: 45.56% (601/1319)
#
# 🎯 METHOD USAGE:
#    Usage Rate: 79.5% (1049/1319 questions)
#
# 📈 ACCURACY BREAKDOWN:
#    With Methods:    43.85% (460/1049)
#    Without Methods: 52.22% (141/270)
#
# 💡 METHOD IMPACT:
#    Difference: -8.37 percentage points
#    ⚠️  Methods DECREASE performance
#
# ❌ Errors: 0
# ================================================================================
#
# ✅ Evaluation complete!
# 📂 Results saved to: results\gemma3_1b_single_evaluation
